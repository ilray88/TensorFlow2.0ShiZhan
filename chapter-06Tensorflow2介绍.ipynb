# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# 定义数据处理方法
def preprocess_dataset(data_frame):
    # 先复制产生一个新的数据集，这样我们的原始数据集不会被修改
    data_frame = data_frame.copy()

    # 丢弃缺失年龄，性别和登船口岸信息的数据
    data_frame = data_frame.dropna(subset=['Age', 'Sex', 'Embarked', 'Fare'])

    # 把性别从 male, female 转换成 0 和 1
    data_frame.Sex = data_frame.Sex.replace(['male', 'female'], value=[0, 1])

    # 把登船口岸从 S, C, Q 转换成 0, 1, 2
    data_frame.Embarked = data_frame.Embarked.replace(['S', 'C', 'Q'], value=[0, 1, 2])

    # 丢弃我们不需要的字段
    data_frame = data_frame.drop(columns=['Name', 'Ticket', 'Cabin', 'PassengerId'])
    return data_frame

# 读取和处理训练数据数据
df = pd.read_csv('data/titanic/train.csv')
train_df = preprocess_dataset(df)

# 拆分特征和标签
train_labels = train_df.pop('Survived')

# 定义模型
from tensorflow.python import keras

# 使用 L 代表 keras.layers ，方便后续调用
L = keras.layers

model = keras.Sequential([
    # 添加一个包含 12 个神经元的全连接层，输入维度为 7，输出维度 12
    L.Dense(12, input_dim=7, activation='relu', name='input_layer'),
    # 添加一个包含 6 个神经元的全连接层，上层的输出为本层的输入
    L.Dense(6, activation='relu', name='hidden_layer'),
    # 添加一个包含 1 个神经元的全连接层，使用 sigmoid 函数来确保网络输出在 0 和 1 之间
    L.Dense(1, activation='sigmoid', name='output_layer')
])

# 编译模型
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## 6.2 模型保存和恢复
# ### 6.2.1 全模型保存

# %%
import tensorflow as tf
import os
# 创建目录
os.makedirs('outputs/chapter6', exist_ok=True)

# 保存模型
model.save('outputs/chapter6/my_model.h5')

# 使用保存的文件恢复模型，此时不需要任何之前的代码，只需要这个文件
new_model = tf.keras.models.load_model('outputs/chapter6/my_model.h5')
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (Dense)          (None, 12)                96
# _________________________________________________________________
# hidden_layer (Dense)         (None, 6)                 78
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 7
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (Dense)          (None, 12)                96
# _________________________________________________________________
# hidden_layer (Dense)         (None, 6)                 78
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 7
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6.2.2 保存为 SavedModel

# %%
# 保存模型为 SavedModel 格式
tf.saved_model.save(model, 'outputs/chapter6/saved_model')
# 加载 SavedModel 模型为 Keras 模型
new_model = tf.keras.models.load_model('outputs/chapter6/saved_model')
# !ls outputs/chapter6/saved_model
# Out:
# WARNING:tensorflow:From D:\0ilraypan\python_work\env\tensorflow2.0\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From D:\0ilraypan\python_work\env\tensorflow2.0\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: outputs/chapter6/saved_model\assets
# 'ls' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。
# INFO:tensorflow:Assets written to: outputs/chapter6/saved_model\assets
# 'ls' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %% [markdown]
# ### 6.2.3 仅保存模型结构

# %%
# 获取模型配置，config 是个 python 字典。
config = model.get_config()

# 使用配置字典重新初始化模型
reinitialized_model = keras.Sequential.from_config(config)

# %% [markdown]
# ### 6.2.4 仅保存模型权重

# %%
weights = model.get_weights()  # 获取模型的权重
model.set_weights(weights)     # 为模型设定权重

# 把权重保存到磁盘
model.save_weights('outputs/chapter6/model_weights.h5')
# 从磁盘加载模型权重
model.load_weights('outputs/chapter6/model_weights.h5')

# %% [markdown]
# ## 6.3 模型增量更新

# %%
# 加载保存模型
new_model = tf.keras.models.load_model('outputs/chapter6/my_model.h5')
# 或加载 SavedModel 格式模型
new_model = tf.keras.models.load_model('outputs/chapter6/saved_model')

# 假数据
new_x = np.random.random((10,7))
new_y = np.random.randint(0, 1, 10)

# 继续调用 fit 训练即可
new_model.fit(new_x, new_y)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6598 - accuracy: 0.8000
# 1/1 [==============================] - 0s 516us/step - loss: 0.7571 - accuracy: 0.1000

# %% [markdown]
# ## 6.4 训练回调
# ### 6.4.1 模型检查点和提前终止

# %%
import tensorflow as tf

# 当被监测的指标不再提升，则停止训练。
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',  # 被监测的指标，这里监控模型验证集准确度
    patience=3)              # 如果指标在多余三轮的时间（即四轮）不变后，中断训练

# 在每个训练期之后保存模型。
model_path = 'outputs/chapter6/best_model.h5'
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=model_path,    # 模型存储路径
    monitor='val_accuracy', # 被监测的指标，这里监控模型验证集准确度
    save_best_only=True)    # 只有指标被改善时候存储，如果为 False，则每一轮保存

model.fit(train_df.values,
          train_labels.values,
          validation_data=(train_df.values, train_labels.values),
          epochs=40,
          callbacks=[early_stop, model_checkpoint])
# Out:
# Epoch 1/40
#  1/23 [>.............................] - ETA: 0s - loss: 1.8284 - accuracy: 0.4062WARNING:tensorflow:Callbacks method `on_test_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_begin` time: 0.0005s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0005s). Check your callbacks.
# 23/23 [==============================] - 0s 12ms/step - loss: 0.9315 - accuracy: 0.6166 - val_loss: 0.7968 - val_accuracy: 0.6882
# Epoch 2/40
# 23/23 [==============================] - 0s 6ms/step - loss: 0.7304 - accuracy: 0.6980 - val_loss: 0.6796 - val_accuracy: 0.7008
# Epoch 3/40
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6596 - accuracy: 0.7051 - val_loss: 0.6416 - val_accuracy: 0.7079
# Epoch 4/40
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6354 - accuracy: 0.7022 - val_loss: 0.6255 - val_accuracy: 0.7121
# Epoch 5/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6263 - accuracy: 0.7163 - val_loss: 0.6353 - val_accuracy: 0.7051
# Epoch 6/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6113 - accuracy: 0.6966 - val_loss: 0.6137 - val_accuracy: 0.7065
# Epoch 7/40
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6090 - accuracy: 0.7093 - val_loss: 0.5964 - val_accuracy: 0.7205
# Epoch 8/40
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5947 - accuracy: 0.7107 - val_loss: 0.5886 - val_accuracy: 0.7233
# Epoch 9/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5894 - accuracy: 0.7233 - val_loss: 0.5831 - val_accuracy: 0.7163
# Epoch 10/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5802 - accuracy: 0.7261 - val_loss: 0.5766 - val_accuracy: 0.7149
# Epoch 11/40
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5762 - accuracy: 0.7219 - val_loss: 0.5689 - val_accuracy: 0.7317
# Epoch 12/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5717 - accuracy: 0.7149 - val_loss: 0.5613 - val_accuracy: 0.7261
# Epoch 13/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5608 - accuracy: 0.7261 - val_loss: 0.5555 - val_accuracy: 0.7289
# Epoch 14/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5555 - accuracy: 0.7289 - val_loss: 0.5498 - val_accuracy: 0.7275
# Epoch 1/40
# 23/23 [==============================] - 0s 9ms/step - loss: 2.1262 - accuracy: 0.4045 - val_loss: 1.6863 - val_accuracy: 0.4031
# Epoch 2/40
# 23/23 [==============================] - 0s 5ms/step - loss: 1.2907 - accuracy: 0.4087 - val_loss: 0.9123 - val_accuracy: 0.4452
# Epoch 3/40
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7986 - accuracy: 0.5829 - val_loss: 0.7615 - val_accuracy: 0.6138
# Epoch 4/40
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7571 - accuracy: 0.6250 - val_loss: 0.7277 - val_accuracy: 0.6362
# Epoch 5/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7285 - accuracy: 0.6278 - val_loss: 0.7105 - val_accuracy: 0.6306
# Epoch 6/40
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7101 - accuracy: 0.6404 - val_loss: 0.6890 - val_accuracy: 0.6447
# Epoch 7/40
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6828 - accuracy: 0.6433 - val_loss: 0.6664 - val_accuracy: 0.6503
# Epoch 8/40
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6646 - accuracy: 0.6615 - val_loss: 0.6541 - val_accuracy: 0.6587
# Epoch 9/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6484 - accuracy: 0.6587 - val_loss: 0.6415 - val_accuracy: 0.6573
# Epoch 10/40
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6400 - accuracy: 0.6587 - val_loss: 0.6316 - val_accuracy: 0.6685
# Epoch 11/40
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6359 - accuracy: 0.6629 - val_loss: 0.6241 - val_accuracy: 0.6728
# Epoch 12/40
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6205 - accuracy: 0.6868 - val_loss: 0.6153 - val_accuracy: 0.6896
# Epoch 13/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6143 - accuracy: 0.6784 - val_loss: 0.6097 - val_accuracy: 0.6798
# Epoch 14/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6149 - accuracy: 0.6756 - val_loss: 0.6072 - val_accuracy: 0.6812
# Epoch 15/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6056 - accuracy: 0.6812 - val_loss: 0.6028 - val_accuracy: 0.6784

# %% [markdown]
# ### 6.4.2 动态调整学习率

# %%
reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor = 'val_loss', # 监控模型的损失
    factor = 0.2,         # 触发时将学习率除以 5
    patience = 10)        # 如果验证损失在 10 轮内都没有改善，那么就触发这个回调函数

model.fit(train_df.values,
          train_labels.values,
          validation_data=(train_df.values, train_labels.values),
          epochs=40,
          callbacks=[reduce_lr_callback])
# Out:
# Epoch 1/40
#  1/23 [>.............................] - ETA: 0s - loss: 0.5897 - accuracy: 0.7500WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 23/23 [==============================] - 0s 3ms/step - loss: 0.5512 - accuracy: 0.7261 - val_loss: 0.5483 - val_accuracy: 0.7528
# Epoch 2/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5470 - accuracy: 0.7374 - val_loss: 0.5412 - val_accuracy: 0.7514
# Epoch 3/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5430 - accuracy: 0.7388 - val_loss: 0.5362 - val_accuracy: 0.7430
# Epoch 4/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.
40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5533 - accuracy: 0.7191 - val_loss: 0.5514 - val_accuracy: 0.7289
# Epoch 27/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5490 - accuracy: 0.7149 - val_loss: 0.5458 - val_accuracy: 0.7303
# Epoch 28/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5463 - accuracy: 0.7219 - val_loss: 0.5430 - val_accuracy: 0.7247
# Epoch 29/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5443 - accuracy: 0.7233 - val_loss: 0.5409 - val_accuracy: 0.7219
# Epoch 30/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5422 - accuracy: 0.7191 - val_loss: 0.5462 - val_accuracy: 0.7317
# Epoch 31/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5416 - accuracy: 0.7261 - val_loss: 0.5406 - val_accuracy: 0.7219
# Epoch 32/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5413 - accuracy: 0.7205 - val_loss: 0.5350 - val_accuracy: 0.7261
# Epoch 33/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5387 - accuracy: 0.7289 - val_loss: 0.5367 - val_accuracy: 0.7205
# Epoch 34/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5394 - accuracy: 0.7303 - val_loss: 0.5323 - val_accuracy: 0.7317
# Epoch 35/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5319 - accuracy: 0.7275 - val_loss: 0.5297 - val_accuracy: 0.7205
# Epoch 36/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5330 - accuracy: 0.7261 - val_loss: 0.5351 - val_accuracy: 0.7219
# Epoch 37/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5298 - accuracy: 0.7233 - val_loss: 0.5260 - val_accuracy: 0.7317
# Epoch 38/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5310 - accuracy: 0.7360 - val_loss: 0.5318 - val_accuracy: 0.7360
# Epoch 39/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5303 - accuracy: 0.7289 - val_loss: 0.5520 - val_accuracy: 0.7247
# Epoch 40/40
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5312 - accuracy: 0.7317 - val_loss: 0.5235 - val_accuracy: 0.7402

# %% [markdown]
# ### 6.4.3 自定义回调函数

# %%
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        # 训练开始时定义一个数组来保存数据
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        # 把每一轮 batch 的 loss 记录到数组中
        self.losses.append(logs.get('loss'))


loss_history_callback = LossHistory()

model.fit(train_df,
          train_labels,
          epochs=10,
          callbacks=[loss_history_callback])
# Out:
# Epoch 1/10
# 23/23 [==============================] - 0s 936us/step - loss: 0.4594 - accuracy: 0.7921
# Epoch 2/10
# 23/23 [==============================] - 0s 890us/step - loss: 0.4575 - accuracy: 0.8020
# Epoch 3/10
# 23/23 [==============================] - 0s 882us/step - loss: 0.4566 - accuracy: 0.8076
# Epoch 4/10
# 23/23 [==============================] - 0s 848us/step - loss: 0.4514 - accuracy: 0.8006
# Epoch 5/10
# 23/23 [==============================] - 0s 827us/step - loss: 0.4605 - accuracy: 0.7963
# Epoch 6/10
# 23/23 [==============================] - 0s 870us/step - loss: 0.4603 - accuracy: 0.7879
# Epoch 7/10
# 23/23 [==============================] - 0s 870us/step - loss: 0.4572 - accuracy: 0.7963
# Epoch 8/10
# 23/23 [==============================] - 0s 851us/step - loss: 0.4534 - accuracy: 0.7893
# Epoch 9/10
# 23/23 [==============================] - 0s 870us/step - loss: 0.4561 - accuracy: 0.7865
# Epoch 10/10
# 23/23 [==============================] - 0s 975us/step - loss: 0.4451 - accuracy: 0.8006
# Epoch 1/10
# 23/23 [==============================] - 0s 895us/step - loss: 0.5224 - accuracy: 0.7317
# Epoch 2/10
# 23/23 [==============================] - 0s 868us/step - loss: 0.5195 - accuracy: 0.7289
# Epoch 3/10
# 23/23 [==============================] - 0s 931us/step - loss: 0.5208 - accuracy: 0.7233
# Epoch 4/10
# 23/23 [==============================] - 0s 871us/step - loss: 0.5161 - accuracy: 0.7402
# Epoch 5/10
# 23/23 [==============================] - 0s 812us/step - loss: 0.5150 - accuracy: 0.7346
# Epoch 6/10
# 23/23 [==============================] - 0s 914us/step - loss: 0.5119 - accuracy: 0.7374
# Epoch 7/10
# 23/23 [==============================] - 0s 838us/step - loss: 0.5123 - accuracy: 0.7346
# Epoch 8/10
# 23/23 [==============================] - 0s 916us/step - loss: 0.5100 - accuracy: 0.7374
# Epoch 9/10
# 23/23 [==============================] - 0s 888us/step - loss: 0.5102 - accuracy: 0.7430
# Epoch 10/10
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5097 - accuracy: 0.7275

# %%
import matplotlib.pyplot as plt
import numpy as np

# 设置 plt 的分辨率，默认分辨率比较低，导致图标不清晰
plt.rcParams['figure.dpi'] = 180

plt.figure()
# 只传入一个参数的话, 默认为 y 轴, x 轴默认为 range(n)
plt.plot(loss_history_callback.losses)
plt.show()

# %% [markdown]
# ## 6.5 Tensorboard 可视化

# %%
tensorboard = keras.callbacks.TensorBoard(
    log_dir='outputs/chapter6/tf_board_log', # 日志输出目录
    histogram_freq=2) # 对于模型中各个层计算激活值和模型权重直方图的频率

model.fit(train_df,
          train_labels,
          epochs=20,
          callbacks=[tensorboard])
# Out:
# Epoch 1/20
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.2908s). Check your callbacks.
# 23/23 [==============================] - 0s 16ms/step - loss: 0.4795 - accuracy: 0.7837
# Epoch 2/20
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4530 - accuracy: 0.7893
# Epoch 3/20
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4501 - accuracy: 0.7978
# Epoch 4/20
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4535 - accuracy: 0.7879
# Epoch 5/20
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4619 - accuracy: 0.7879
# Epoch 6/20
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4481 - accuracy: 0.7879
# Epoch 7/20
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4511 - accuracy: 0.7851
# Epoch 8/20
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4471 - accuracy: 0.7978
# Epoch 9/20
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4490 - accuracy: 0.7992
# Epoch 10/20
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4449 - accuracy: 0.7921
# Epoch 11/20
#  - 0s 3ms/step - loss: 0.4424 - accuracy: 0.8062
# Epoch 12/20
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4442 - accuracy: 0.7879
# Epoch 13/20
#  - 0s 3ms/step - loss: 0.4455 - accuracy: 0.7879
# Epoch 14/20
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4459 - accuracy: 0.7893
# Epoch 15/20
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4443 - accuracy: 0.7893
# Epoch 16/20
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4432 - accuracy: 0.7921
# Epoch 17/20
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4453 - accuracy: 0.7949
# Epoch 18/20
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4394 - accuracy: 0.7921
# Epoch 19/20
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4394 - accuracy: 0.7837
# Epoch 20/20
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4464 - accuracy: 0.7921

# %%
tensorboard --logdir==D:\0ilraypan\git_jia\Tensorflow 2.0实战\outputs\chapter6\tf_board_log

# %%
import datetime
print(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2021-10-29 10:09:11
# 2021-10-29 10:09:21
